# %%
pip install yacs dlutils
# Out:
# ...
# WARNING: You are using pip version 19.2.1, however version 20.2.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall scipy --yes
# Out:
# Uninstalling scipy-1.3.0:
#   Successfully uninstalled scipy-1.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scipy==1.1.0
# Out:
# ...
# WARNING: You are using pip version 19.2.1, however version 20.2.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# !python partition_mnist.py
# Out:
# Downloading: train-images-idx3-ubyte.gz Bytes: 9912422
#    9912422  [100.00%]
# Extracting...
# Done
# Downloading: train-labels-idx1-ubyte.gz Bytes: 28881
#      28881  [100.00%]
# Extracting...
# Done
# Downloading: t10k-images-idx3-ubyte.gz Bytes: 1648877
#    1648877  [100.00%]
# Extracting...
# Done
# Downloading: t10k-labels-idx1-ubyte.gz Bytes: 4542
#       4542  [100.00%]
# Extracting...
# Done
# 13996
# 13996
# 13996
# 13996
# 13996

# %%
### IMPORTANT FROM HERE 
### EPOCH=80
### LOSS = UNCHANGED
### LAYERS= UNCHANGED

# %%
# !python schedule.py
# Out:
# Running on GPU: 0, Quadro P5000
# 2020-09-01 10:15:45,985 logger INFO: Train set size: 4140
# Progress: |###################################################| 100.0% [33/33]
# 2020-09-01 10:15:53,726 logger INFO: [1/80] - ptime: 5.06, D: 6.7089829, G: 8.2284956, ZD: 0.6650773, GE: 71933.8828125, E: 0.2884754
# Progress: |###################################################| 100.0% [33/33]
# 2020-09-01 10:15:59,104 logger INFO: [2/80] - ptime: 5.07, D: 2.2455437, G: 1.4444239, ZD: 0.0447543, GE: 49540.1484375, E: 0.0033943
# Progress: |###################################################| 100.0% [33/33]
# 2020-09-01 10:16:04,434 logger INFO: [3/80] - ptime: 5.04, D: 1.8502846, G: 1.4007765, ZD: 0.0138948, GE: 47311.9296875, E: 0.0016306
# Progress: |###################################################| 100.0% [33/33]
# 2020-09-01 10:16:09,767 logger INFO: [4/80] - ptime: 5.07, D: 1.7444408, G: 1.2126249, ZD: 0.0082870, GE: 45944.7070312, E: 0.0015845
# ...

# %%
### IMPORTANT FROM HERE 
### EPOCH=100
### LOSS = UNCHANGED
### LAYERS= UNCHANGED

# %%
# !python schedule.py
# Out:
# Running on GPU: 0, Quadro P5000
# 2020-09-01 12:18:09,130 logger INFO: Train set size: 4140
# Progress: |###################################################| 100.0% [33/33]
# 2020-09-01 12:18:17,047 logger INFO: [1/80] - ptime: 5.10, D: 4.1710582, G: 8.6681862, ZD: 0.9289511, GE: 92988.4609375, E: 2.4277501
# Progress: |###################################################| 100.0% [33/33]
# 2020-09-01 12:18:22,452 logger INFO: [2/80] - ptime: 5.06, D: 2.2354009, G: 1.9433879, ZD: 0.2605166, GE: 60892.9609375, E: 3.8702095
# Progress: |###################################################| 100.0% [33/33]
# 2020-09-01 12:18:27,822 logger INFO: [3/80] - ptime: 5.08, D: 1.8731887, G: 1.5458066, ZD: 0.0777755, GE: 54439.7109375, E: 5.2854438
# Progress: |###################################################| 100.0% [33/33]
# 2020-09-01 12:18:33,218 logger INFO: [4/80] - ptime: 5.11, D: 1.7729686, G: 1.2340440, ZD: 0.0431873, GE: 49561.0351562, E: 4.9274602
# ...

# %%
### IMPORTANT FROM HERE 
### EPOCH=80
### LOSS = CHANGED
### LAYERS+ UNCHANGED

# %%
# !python schedule.py
# Out:
# Running on GPU: 0, Quadro P5000
# 2020-09-01 16:06:56,890 logger INFO: Train set size: 4140
# Progress: |###################################################| 100.0% [33/33]
# 2020-09-01 16:07:05,926 logger INFO: [1/80] - ptime: 5.32, D: 5.1790314, G: 9.7579098, ZD: 0.6270463, GE: 54062384.0000000, E: 1.4653361
# Progress: |###################################################| 100.0% [33/33]
# 2020-09-01 16:07:11,696 logger INFO: [2/80] - ptime: 5.28, D: 2.6763093, G: 2.2391694, ZD: 0.0212730, GE: 93091.2890625, E: 1.7282821
# Progress: |###################################################| 100.0% [33/33]
# 2020-09-01 16:07:17,382 logger INFO: [3/80] - ptime: 5.30, D: 2.1494858, G: 1.6246740, ZD: 0.0045343, GE: 80671.4609375, E: 2.3309171
# Progress: |###################################################| 100.0% [33/33]
# 2020-09-01 16:07:23,164 logger INFO: [4/80] - ptime: 5.28, D: 2.0579085, G: 1.3630993, ZD: 0.0015621, GE: 77690.7343750, E: 1.8328351
# ...

# %%
### IMPORTANT FROM HERE 
### EPOCH=80
### LOSS = UCHANGED
### LAYERS=CHANGED

# %%
# !python schedule.py
# Out:
# Running on GPU: 0, Quadro P5000
# 2020-09-01 18:29:05,087 logger INFO: Train set size: 4140
# Progress: |###################################################| 100.0% [33/33]
# 2020-09-01 18:29:13,854 logger INFO: [1/80] - ptime: 5.26, D: 4.1038642, G: 7.5530319, ZD: 0.7564537, GE: 77079.1718750, E: 2.7636826
# Progress: |###################################################| 100.0% [33/33]
# 2020-09-01 18:29:19,514 logger INFO: [2/80] - ptime: 5.23, D: 2.4842567, G: 1.8586917, ZD: 0.3388951, GE: 55931.0078125, E: 5.3689070
# Progress: |###################################################| 100.0% [33/33]
# 2020-09-01 18:29:25,144 logger INFO: [3/80] - ptime: 5.23, D: 1.9313505, G: 1.3468279, ZD: 0.2157671, GE: 50838.8945312, E: 6.0734868
# Progress: |###################################################| 100.0% [33/33]
# 2020-09-01 18:29:30,704 logger INFO: [4/80] - ptime: 5.21, D: 1.8844472, G: 1.2205535, ZD: 0.0980287, GE: 49294.8125000, E: 8.0364132
# ...

# %%
### IMPORTANT FROM HERE 
### EPOCH=100
### LOSS = UCHANGED
### LAYERS=CHANGED

# %%
# !python schedule.py
# Out:
# Running on GPU: 0, Quadro P5000
# 2020-09-03 09:34:55,324 logger INFO: Train set size: 4140
# Progress: |###################################################| 100.0% [33/33]
# 2020-09-03 09:35:03,314 logger INFO: [1/100] - ptime: 5.05, D: 4.1887350, G: 6.6860905, ZD: 0.7506280, GE: 75648.4218750, E: 2.7696984
# Progress: |###################################################| 100.0% [33/33]
# 2020-09-03 09:35:08,615 logger INFO: [2/100] - ptime: 5.00, D: 2.2925367, G: 1.9181534, ZD: 0.3877041, GE: 53783.3828125, E: 4.8131113
# Progress: |###################################################| 100.0% [33/33]
# 2020-09-03 09:35:13,952 logger INFO: [3/100] - ptime: 5.03, D: 1.8978204, G: 1.4736650, ZD: 0.2121549, GE: 51610.5234375, E: 6.1060629
# Progress: |###################################################| 100.0% [33/33]
# 2020-09-03 09:35:19,257 logger INFO: [4/100] - ptime: 5.02, D: 1.8472415, G: 1.2365962, ZD: 0.1327977, GE: 47846.9453125, E: 7.8928113
# ...

# %%
### IMPORTANT FROM HERE 
### EPOCH=100--Standard
### LOSS = CHANGED
### LAYERS=CHANGED--standard

# %%
# !python schedule.py
# Out:
# Running on GPU: 0, Quadro P5000
# 2020-09-04 13:16:32,285 logger INFO: Train set size: 4140
#  cfg.TRAIN.BATCH_SIZE :128
# Progress: |###################################################| 100.0% [33/33]
# 2020-09-04 13:16:40,579 logger INFO: [1/100] - ptime: 5.14, D: 4.0529675, G: 8.5366488, ZD: 1.2661396, GE: 7.8903031, RE: 38442.9804688, K: 1008.5439453, E: 1.0401177
# ^C
# Traceback (most recent call last):
#   File "schedule.py", line 44, in <module>
#     results = utils.multiprocessing.map(f, gpu_count, settings)
#   File "/notebooks/utils/multiprocessing.py", line 68, in map
#     return p.map(functools.partial(_f, func), iteratable)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 266, in map
#     return self._map_async(func, iterable, mapstar, chunksize).get()
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 638, in get
#     self.wait(timeout)
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 635, in wait
#     self._event.wait(timeout)
# ...

# %%
### IMPORTANT FROM HERE 
### EPOCH=100--Standard
### LOSS = CHANGED-- This shit is the problem mate
### LAYERS=CHANGED--standard
### LR=0.0001

# %%
# !python schedule.py
# Out:
# Running on GPU: 0, Quadro P5000
# 2020-09-04 21:39:20,992 logger INFO: Train set size: 4140
#  cfg.TRAIN.BATCH_SIZE :128
# Progress: |###################################################| 100.0% [33/33]
# 2020-09-04 21:39:29,062 logger INFO: [1/200] - ptime: 5.19, D: 0.0745580, G: 5.7147117, ZD: 1.3773049, GE: 11.7057257, RE: 57823.4335938, K: 705.1857910, E: 0.7027552
#  cfg.TRAIN.BATCH_SIZE :128
# Progress: |###################################################| 100.0% [33/33]
# 2020-09-04 21:39:34,568 logger INFO: [2/200] - ptime: 5.16, D: 0.4107624, G: 4.4919457, ZD: 1.3306345, GE: 6.6462421, RE: 31914.7617188, K: 1316.4530029, E: 0.7536123
#  cfg.TRAIN.BATCH_SIZE :128
# Progress: |###################################################| 100.0% [33/33]
# 2020-09-04 21:39:40,069 logger INFO: [3/200] - ptime: 5.18, D: 0.5274485, G: 2.9947674, ZD: 1.2428747, GE: 5.6992717, RE: 27008.9160156, K: 1487.4440918, E: 0.8720222
#  cfg.TRAIN.BATCH_SIZE :128
# ...

# %%
# !nvidia-smi
# Out:
# Thu Sep  3 09:25:35 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.36.06    Driver Version: 450.36.06    CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro P5000        On   | 00000000:00:05.0 Off |                 ERR! |
# | 26%   24C    P8    10W / 180W |      1MiB / 16278MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...
